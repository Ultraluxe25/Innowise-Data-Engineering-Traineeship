# %% [markdown]
# # Python for solving practical problems (Mikhail Gustokashin)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from urllib.request import urlopen

# %% [markdown]
# # [urllib.request.urlopen](https://docs.python.org/3/library/urllib.request.html)

# %%
# Link to object
html = urlopen("https://ru.wikipedia.org/wiki/Python")
html

# %%
# You can launch only once
text = str(html.read().decode('utf-8'))
text[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="ru" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Python — Википедия</title>\n<script>document.documentElement.className="client-js";(function(){var cookie=document.cookie.match(/(?:^|; )ruwikimwclientprefs=([^;]+)/);if(cookie){var featureName=cookie[1];document.documentElement.className=document.documentElement.className.replace(featureName+\'-enabled\',featureName+\'-disabled\');}}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","январь","февраль","март","апрель","май","июнь","июль","август","сентябрь","октябрь","ноябрь","декабрь"],"wgRequestId":"10a713e0-39b3-4de5-b8ac-d2cd7c949a33","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Python","wgTitle":"Python","wgCurRevisionId":130859662,"wgRevisionId":130859662,"wgArticleId":2705,"wgIsArticle":true,"wg
# ...

# %%
# Install beautiful soup
# !pip install beautifulsoup4

# %%
# Launch BS4
from bs4 import BeautifulSoup

# %%
# Task 1.1 - output result
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup

resp = urlopen('https://stepik.org/media/attachments/lesson/245130/6.html')
html = resp.read().decode('utf-8')  # read content
soup = BeautifulSoup(html, 'html.parser')  # make soup

table = soup.find('table', attrs={'class': 'wikitable sortable'})
cnt = 0
for tr in soup.find_all('tr'):
    cnt += 1
    for td in tr.find_all(['td', 'th']):
        cnt *= 2
print(cnt)
# Out:
# 94596065609609271052308

# %% [markdown]
# # <span style="color: red">To be continued</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span style="color: blue">Beautiful Soup Documentation</span>

# %% [markdown]
# ### Beautiful Soup is a Python library for extracting data from HTML and XML files.

# %%
# This is an excerpt from Alice in Wonderland:

html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
# Import library and make soup
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, 'html.parser')

# %%
# Make code better
print(soup.prettify())  # be sure to use print
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Here are some easy ways to navigate

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
print(soup.title.string)  # print removes quotes
# Out:
# The Dormouse's story

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
# Find all tags <a>
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id='link3')
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
# Retrieve all URL from site
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
# Retrieve all text from site
print(soup.get_text())
soup.get_text()
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
# "\nThe Dormouse's story\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %% [markdown]
# ##### I recommend installing and using lxml whenever possible for speed

# %% [markdown]
# ##### <span style="color: brown">You have to deal with four kinds of objects: Tag, NavigableString, BeautifulSoup, and Comment</span>

# %% [markdown]
# # <span style="color: red">To be continued</span>
